# %%
import pandas as pd
import numpy as np

# %%
url = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'
df_isp = pd.read_csv(url, encoding= 'latin1', sep=';')
df.head(3)
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2     5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
# 2           3  ...  NaN   NaN      47                      2
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
# 2                 1                0                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
# ...

# %%
df.tail(2)
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp      munic    mcirc    regiao  \
# 38134   167    7  2026  2026m07    43     5     Paraty  3303807   Capital
# 38135   168    7  2026  2026m07    28     5  Rio Claro  3304409  Interior
#
#        hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 38134           1  ...  3.0   0.0      27                      2
# 38135           0  ...  0.0   0.0       4                      2
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 38134                 1                0                          0
# 38135                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 38134                      0                   206     2
# 38135                      0                    52     2
#
# [2 rows x 65 columns]

# %%
df.columns
# Out:
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'feminicidio', 'letalidade_violenta',
#        'tentat_hom', 'tentativa_feminicidio', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_transeunte',
#        'roubo_celular', 'roubo_em_coletivo', 'roubo_rua', 'roubo_veiculo',
#        'roubo_carga', 'roubo_comercio', 'roubo_residencia', 'roubo_banco',
#        'roubo_cx_eletronico', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38136 entries, 0 to 38135
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cisp                        38136 non-null  int64
#  1   mes                         38136 non-null  int64
#  2   ano                         38136 non-null  int64
#  3   mes_ano                     38136 non-null  str
#  4   aisp                        38136 non-null  int64
#  5   risp                        38136 non-null  int64
#  6   munic                       38136 non-null  str
#  7   mcirc                       38136 non-null  int64
#  8   regiao                      38136 non-null  str
#  9   hom_doloso                  38136 non-null  int64
#  10  lesao_corp_morte            38136 non-null  int64
#  11  latrocinio                  38136 non-null  int64
#  12  cvli                        38136 non-null  int64
# ...

# %%
df.head(2)
# Out:
#    cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0     1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1     4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
#
#    hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0           0  ...  NaN   NaN      21                      2
# 1           3  ...  NaN   NaN      15                      6
#
#    encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                 0                0                          0
# 1                 0                1                          0
#
#    pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                      0                   578     3
# 1                      0                   441     3
#
# [2 rows x 65 columns]

# %%
df_furto_cel_dp = df.groupby('cisp')['furto_celular'].sum().reset_index()
df_furto_cel_dp.sort_values(by='furto_celular', ascending = False,inplace=True)
df_furto_cel_dp
# Out:
#      cisp  furto_celular
# 12     16          26230
# 2       5          25737
# 10     14          19004
# 8      12          17630
# 0       1          16185
# ..    ...            ...
# 41     45             73
# 77     92             65
# 114   138             56
# 131   157             55
# 129   155             47
#
# [138 rows x 2 columns]

# %%
df_aaapai_dp = df.groupby('cisp')['aaapai'].sum().reset_index()
df_aaapai_dp = df_aaapai_dp.sort_values(by='aaapai', ascending = False)
df_aaapai_dp
# Out:
#      cisp  aaapai
# 104   126  3736.0
# 8      12  3667.0
# 10     14  3368.0
# 65     74  3355.0
# 12     16  3233.0
# ..    ...     ...
# 130   156    19.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %%
df_roubo_veiculo_dp = df.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_roubo_veiculo_dp = df_roubo_veiculo_dp.sort_values(by='roubo_veiculo', ascending = False)
df_roubo_veiculo_dp
# Out:
#      cisp  roubo_veiculo
# 52     59          37866
# 57     64          32892
# 35     39          29753
# 23     27          27978
# 30     34          27596
# ..    ...            ...
# 77     92              8
# 116   140              8
# 115   139              7
# 113   137              6
# 114   138              2
#
# [138 rows x 2 columns]

# %%
munic_pedido=['Belford ROxo','Nova Iguaçu','Queimados']

df_bel_nov_quei=df.loc[df['munic'].isin(munic_pedido)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df_roubo_veiculo_dp_bel=df_bel.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_roubo_veiculo_dp_bel=df_roubo_veiculo_dp_bel.sort_values(by='roubo_veiculo',ascending=False)
df_roubo_veiculo_dp_bel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 df_roubo_veiculo_dp_bel=df_bel.groupby('cisp')['roubo_veiculo'].sum().reset_index()
#       2 df_roubo_veiculo_dp_bel=df_roubo_veiculo_dp_bel.sort_values(by='roubo_veiculo',ascending=False)
#       3 df_roubo_veiculo_dp_bel
#
# NameError: name 'df_bel' is not defined

# %%
array_furto_cel_cdp= np.array(df_furto_cel_dp['furto_celular'])
array_furto_cel_cdp
# Out:
# array([26230, 25737, 19004, 17630, 16185, 15367, 14842, 14504, 14339,
#        12898, 12278,  8952,  8882,  8754,  8377,  8301,  8192,  7865,
#         7388,  7344,  7074,  6991,  6691,  6657,  6218,  5793,  5692,
#         5625,  5464,  5389,  5070,  4988,  4776,  4768,  4723,  4680,
#         4193,  4150,  4140,  4059,  3891,  3853,  3798,  3770,  3552,
#         3435,  3381,  3301,  3165,  3014,  2992,  2879,  2829,  2726,
#         2618,  2418,  2398,  2366,  2335,  2219,  2168,  2154,  2145,
#         2138,  2097,  1845,  1844,  1831,  1763,  1720,  1670,  1638,
#         1554,  1488,  1476,  1446,  1394,  1386,  1311,  1250,  1154,
#         1096,  1053,  1044,  1041,   941,   836,   824,   812,   752,
#          745,   663,   662,   637,   634,   627,   585,   569,   517,
#          516,   507,   501,   464,   453,   451,   443,   414,   405,
#          387,   376,   369,   362,   357,   304,   303,   261,   245,
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.boxplot(array_furto_cel_cdp, orientation='horizontal',showmeans=True)
plt.show()

# %%
minimo=np.min(array_furto_cel_cdp)
max=np.max(array_furto_cel_cdp)
aplitude=max-minimo
media=np.mean(array_furto_cel_cdp)
mediana=np.median(array_furto_cel_cdp)
q1=np.percentile(array_furto_cel_cdp,25)
q2=np.percentile(array_furto_cel_cdp,50)
q3=np.percentile(array_furto_cel_cdp,75)

print(f'Media {media}\n Mediana {mediana}')
print(f'q1:{q1}')
print(f'q2:{q2}')
print(f'q3:{q3}')
print(f'minimo{minimo} o maximo é {max} e a amplitude é {aplitude}')
# Out:
# Media 3554.4347826086955
#  Mediana 1741.5
# q1:455.75
# q2:1741.5
# q3:4712.25
# minimo47 o maximo é 26230 e a amplitude é 26183

# %%
distancia=(media-mediana)/mediana
print(f'bqbq {distancia:.2%}')
# Out:
# bqbq 104.10%

# %%
df_roubo_veiculo_dp = df.groupby('cisp')['roubo_veiculo'].sum().reset_index()
df_roubo_veiculo_dp=df_roubo_veiculo_dp.sort_values(by='roubo_veiculo',ascending=False)
df_roubo_veiculo_dp
# Out:
#      cisp  roubo_veiculo
# 52     59          37866
# 57     64          32892
# 35     39          29753
# 23     27          27978
# 30     34          27596
# ..    ...            ...
# 77     92              8
# 116   140              8
# 115   139              7
# 113   137              6
# 114   138              2
#
# [138 rows x 2 columns]

# %%
array_roubo_veiculo_dp= np.array(df_roubo_veiculo_dp['roubo_veiculo'])
media_veiculo=np.mean(array_roubo_veiculo_dp)
mediana_veiculo=np.median(array_roubo_veiculo_dp)
q1_veiculo=np.percentile(array_roubo_veiculo_dp,25)
q2_veiculo=np.percentile(array_roubo_veiculo_dp,50)
q3_veiculo=np.percentile(array_roubo_veiculo_dp,75)

# %%
print(f'Media {media_veiculo}\n Mediana {mediana_veiculo}')
print(f'q1:{q1_veiculo}')
print(f'q2:{q2_veiculo}')
print(f'q3:{q3_veiculo}')
# Out:
# Media 5260.95652173913
#  Mediana 1228.5
# q1:104.0
# q2:1228.5
# q3:8125.0

# %%
df_aaapai_dp = df.groupby('cisp')['aaapai'].sum().reset_index()
df_aaapai_dp = df_aaapai_dp.sort_values(by='aaapai', ascending = False)
df_aaapai_dp
# Out:
#      cisp  aaapai
# 104   126  3736.0
# 8      12  3667.0
# 10     14  3368.0
# 65     74  3355.0
# 12     16  3233.0
# ..    ...     ...
# 130   156    19.0
# 129   155    16.0
# 131   157    14.0
# 94    111    13.0
# 77     92    12.0
#
# [138 rows x 2 columns]

# %%
array_aaapai_dp= np.array(df_aaapai_dp['aaapai'])
media_aaapi=np.mean(array_aaapai_dp)
mediana_aaapi=np.median(array_aaapai_dp)
q1_aaapi=np.percentile(array_aaapai_dp,25)
q2_aaapi=np.percentile(array_aaapai_dp,50)
q3_aaapi=np.percentile(array_aaapai_dp,75)
distancia_aaaapai=(media_aaapi-mediana_aaapi)/mediana_aaapi
print(f'rrrr {distancia_aaaapai:.2%}')
# Out:
# rrrr 32.70%

# %%
df_dados={
    'aluno':['Ana','Bruno','Carol','Diego','Elisa','Felipe','Gabi','Hugo'],
    'notas':[8.5,6,9.2,5.5,7.8,4.0,9.0,6.5],
    'horas_estudo':[6,3,8,2,5,1,7,4]}
df=pd.DataFrame(df_dados)
df
# Out:
#     aluno  notas  horas_estudo
# 0     Ana    8.5             6
# 1   Bruno    6.0             3
# 2   Carol    9.2             8
# 3   Diego    5.5             2
# 4   Elisa    7.8             5
# 5  Felipe    4.0             1
# 6    Gabi    9.0             7
# 7    Hugo    6.5             4

# %%
array_notas=np.array(df['notas'])
array_hora=np.array(df['horas_estudo'])

variancia=np.array(df['notas'])
variancia_=np.var(df['notas'])

'''desvio=np.std(array)
print(f"desvio padrão: {desvio:.2f}")
media=np.mean(array)
print(f"media das notas: {media:.2f}")
print(f"faixa tipica:{media-desvio:.2f} ate {media+desvio}")'''
# Out:
# 'desvio=np.std(array)\nprint(f"desvio padrão: {desvio:.2f}")\nmedia=np.mean(array)\nprint(f"media das notas: {media:.2f}")\nprint(f"faixa tipica:{media-desvio:.2f} ate {media+desvio}")'

# %%
array_nota=np.array(df['notas'])
array_hora=np.array(df['horas_estudo'])
matriz_cov=np.cov(array_nota,array_hora)
print(matriz_cov)
# Out:
# [[3.45696429 4.47857143]
#  [4.47857143 6.        ]]

# %%
r=np.corrcoef(array_nota,array_hora)
print(f"pearson r= {r[0,1]:.4f}")
corr_pandas=df[['notas','horas_estudo']].corr()
print(corr_pandas)
# Out:
# pearson r= 0.9834
#                  notas  horas_estudo
# notas         1.000000      0.983369
# horas_estudo  0.983369      1.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.scatter(array_hora,array_nota,color='steelblue',edgecolor='black',s=80)
plt.title('horas de estudo vs. nota')
plt.xlabel('horas de estudo')
plt.ylabel('nota')
plt.show()

# %%
import seaborn as sns
correlacao=np.corrcoef(array_nota,array_hora)
sns.heatmap(correlacao,annot=True,
cmap='coolwarm',vmin=-1,vmax=1,
fmt='.2f')
# Out:
# <Axes: >

# %%
array_desaparecida=np.array(df_isp['pessoas_desaparecidas'])
array_cadaver=np.array(df_isp['encontro_cadaver'])
correlacao_pm=np.corrcoef(array_pm_morto,array_apreensao)
matriz_cov_pm=np.cov(array_pm_morto,array_apreensao)

plt.figure(figsize=(15,10))
plt.scatter(array_cadaver,array_desaparecida,color='steelblue',s=80)
plt.title('pessoa desaparecida vs cadaver')
plt.xlabel('sequestro')
plt.ylabel('cadaver')
plt.show()
