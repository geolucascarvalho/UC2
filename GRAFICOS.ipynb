# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dados = {'categorias': ['Eletrônicos', 'Roupas', 'Alimentos', 'Casa'],
         'valores' : [4200, 2800, 3600, 1900]}

df = pd.DataFrame(dados)

# %%
plt.bar(categorias, valores)
plt.title('Total de Vendas por Categoria — NaraStore')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 plt.bar(categorias, valores)
#       2 plt.title('Total de Vendas por Categoria — NaraStore')
#       3 plt.show()
#
# NameError: name 'categorias' is not defined

# %%
df = pd.read_csv('vendas_narastore.csv')

df_cat = df.groupby('categoria')['total_venda'].sum().reset_index().sort_values(by='total_venda', ascending= False)

plt.bar(df_cat['categoria'], df_cat['total_venda'])
plt.title('Total de Vendas por Categoria — NaraStore')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.barh(df_cat['categoria'], df_cat['total_venda'])
plt.title('Total de Vendas por Categoria — NaraStore')
plt.xticks(rotation=45)
plt.show()
